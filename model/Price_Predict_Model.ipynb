# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
# Read data set
df1 = pd.read_csv("Downloads/housingprices.csv")
df1.head()
# Out:
#                                            SALE TYPE      SOLD DATE  \
# 0  In accordance with local MLS rules, some MLS l...            NaN
# 1                                          PAST SALE            NaN
# 2                                          PAST SALE            NaN
# 3                                          PAST SALE  March-19-2025
# 4                                          PAST SALE            NaN
#
#                PROPERTY TYPE                 ADDRESS         CITY  \
# 0                        NaN                     NaN          NaN
# 1  Single Family Residential       11608 Everston St      Norwalk
# 2                Condo/Co-op  20134 Leadwell St #314     Winnetka
# 3                Condo/Co-op       730 W 4th St #108   Long Beach
# 4  Single Family Residential           648 E 75th St  Los Angeles
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  ... STATUS  \
# 0               NaN                NaN       NaN   NaN    NaN  ...    NaN
# 1                CA              90650  420000.0   3.0    1.0  ...    NaN
# 2                CA              91306  415000.0   2.0    2.0  ...    NaN
# 3                CA              90802  410000.0   1.0    2.0  ...   Sold
# 4                CA              90001  415000.0   2.0    1.0  ...    NaN
#
#    NEXT OPEN HOUSE START TIME  NEXT OPEN HOUSE END TIME  \
# 0                         NaN                       NaN
# 1                         NaN                       NaN
# 2                         NaN                       NaN
# 3                         NaN                       NaN
# 4                         NaN                       NaN
#
#    URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0                                                NaN
# 1  https://www.redfin.com/CA/Norwalk/11608-Everst...
# 2  https://www.redfin.com/CA/Winnetka/20134-Leadw...
# 3  https://www.redfin.com/CA/Long-Beach/730-W-4th...
# 4  https://www.redfin.com/CA/Los-Angeles/648-E-75...
#
#    SOURCE        MLS#  FAVORITE INTERESTED   LATITUDE   LONGITUDE
# 0     NaN         NaN       NaN        NaN        NaN         NaN
# 1     NaN         NaN         N          Y  33.897497 -118.085962
# 2     NaN         NaN         N          Y  34.203220 -118.572588
# 3   CRMLS  PW25054577         N          Y  33.771293 -118.201627
# 4     NaN         NaN         N          Y  33.971871 -118.263439
#
# [5 rows x 27 columns]

# %%
df1.columns
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %%
df2 = df1.drop(['SALE TYPE','SOLD DATE', 'ADDRESS','STATE OR PROVINCE',
                 'LOCATION', 'ZIP OR POSTAL CODE', 'DAYS ON MARKET',
                'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
       'NEXT OPEN HOUSE END TIME',
       'URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
                'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE','$/SQUARE FEET'
               ], axis='columns')
df2.head(20)
# Out:
#                 PROPERTY TYPE         CITY     PRICE  BEDS  BATHS  \
# 0                         NaN          NaN       NaN   NaN    NaN
# 1   Single Family Residential      Norwalk  420000.0   3.0    1.0
# 2                 Condo/Co-op     Winnetka  415000.0   2.0    2.0
# 3                 Condo/Co-op   Long Beach  410000.0   1.0    2.0
# 4   Single Family Residential  Los Angeles  415000.0   2.0    1.0
# 5                 Condo/Co-op   Long Beach  415000.0   1.0    1.0
# 6   Single Family Residential   Littlerock  420000.0   3.0    2.0
# 7     Multi-Family (2-4 Unit)   Littlerock  405000.0   1.0    2.0
# 8   Single Family Residential    Lancaster  405000.0   4.0    2.0
# 9   Single Family Residential   Littlerock  409000.0   3.0    2.0
# 10  Single Family Residential     Palmdale  420000.0   2.0    2.0
# 11  Single Family Residential    Lancaster  410000.0   4.0    2.0
# 12  Single Family Residential  Los Angeles  415000.0   2.0    1.0
# 13  Single Family Residential    Lancaster  420000.0   4.0    2.0
# 14  Single Family Residential    Lancaster  417000.0   3.0    2.0
# 15  Single Family Residential    Lancaster  405000.0   3.0    2.0
# 16  Single Family Residential     Palmdale  412500.0   3.0    2.0
# 17  Single Family Residential    Lancaster  417500.0   4.0    2.0
# 18  Single Family Residential    Lancaster  410000.0   3.0    2.0
# 19                Condo/Co-op  Los Angeles  407000.0   NaN    1.0
#
#     SQUARE FEET  LOT SIZE  YEAR BUILT
# 0           NaN       NaN         NaN
# 1        1122.0    5938.0      1950.0
# 2         884.0       NaN      1971.0
# 3         584.0   32286.0      1987.0
# 4        1166.0    5102.0      1923.0
# 5         687.0       NaN      1958.0
# 6        1247.0    8105.0      1979.0
# 7         820.0   40071.0      1954.0
# 8        1464.0    9331.0      1955.0
# 9        1050.0   33475.0      1983.0
# 10       1065.0    4150.0      1988.0
# 11       1606.0    8095.0      1984.0
# 12        966.0    4800.0      1938.0
# 13       1574.0    7410.0      1972.0
# 14       1449.0    6243.0      1987.0
# 15       1375.0    9130.0      1949.0
# 16       1362.0    7121.0      1992.0
# 17       1516.0    8646.0      1970.0
# 18       1139.0    7537.0      1991.0
# 19        602.0       NaN      1990.0

# %%
df2.isnull().sum()
# Out:
# PROPERTY TYPE      91
# CITY              111
# PRICE              91
# BEDS              234
# BATHS             248
# SQUARE FEET       267
# LOT SIZE         2873
# YEAR BUILT        279
# dtype: int64

# %%
df2.shape
# Out:
# (29201, 8)

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# PROPERTY TYPE    0
# CITY             0
# PRICE            0
# BEDS             0
# BATHS            0
# SQUARE FEET      0
# LOT SIZE         0
# YEAR BUILT       0
# dtype: int64

# %%
df3['BATHS'].unique()
# Out:
# array([ 1. ,  2. ,  3. ,  1.5,  2.5,  4. ,  3.5,  6. ,  8. ,  7. ,  5. ,
#         4.5,  5.5,  7.5,  6.5,  9. , 12. , 14. , 28. , 22. ,  9.5,  8.5,
#        10. , 11. , 10.5])

# %%
len(df3.CITY.unique())
# Out:
# 263

# %%
df4 = df3.copy()
df4.CITY = df4.CITY.apply(lambda x: x.strip())
city_stats = df4.groupby("CITY")["CITY"].agg("count").sort_values(ascending = False)
city_stats
# Out:
# CITY
# Los Angeles                3477
# Long Beach                  984
# Lancaster                   813
# Palmdale                    624
# Whittier                    420
#                            ...
# San Pedro (los Angeles)       1
# Lake Forest (el Toro)         1
# Lennox                        1
# Glassell Park                 1
# Pacoima (los Angeles)         1
# Name: CITY, Length: 263, dtype: int64

# %%
len(city_stats[city_stats <= 10])
# Out:
# 80

# %%
city_stats_less_than_10 = city_stats[city_stats<=10]
df4.CITY = df4.CITY.apply(lambda x: "other" if x in city_stats_less_than_10 else x)
len(df4.CITY.unique())
# Out:
# 184

# %%
df4.groupby('BATHS')['BATHS'].agg('count')
# Out:
# BATHS
# 1.0      3696
# 1.5       868
# 2.0     10137
# 2.5      3312
# 3.0      4699
# 3.5      1022
# 4.0       920
# 4.5       566
# 5.0       331
# 5.5       260
# 6.0       161
# 6.5        67
# 7.0        56
# 7.5        16
# 8.0        27
# 8.5         9
# 9.0        11
# 9.5         5
# 10.0        2
# 10.5        2
# 11.0        2
# 12.0        4
# 14.0        1
# 22.0        1
# 28.0        1
# Name: BATHS, dtype: int64

# %%
df4['SQUARE FEET']
df4 = df4[df4['SQUARE FEET'] > 1]
df4.groupby('SQUARE FEET')['SQUARE FEET'].agg('count')
# Out:
# SQUARE FEET
# 210.0      1
# 288.0      1
# 290.0      1
# 300.0      1
# 330.0      1
#           ..
# 13365.0    1
# 14609.0    1
# 15292.0    1
# 16080.0    1
# 25648.0    1
# Name: SQUARE FEET, Length: 3963, dtype: int64

# %%
df4[df4['SQUARE FEET'] / df4.BEDS < 50].head()
# Out:
# Empty DataFrame
# Columns: [PROPERTY TYPE, CITY, PRICE, BEDS, BATHS, SQUARE FEET, LOT SIZE, YEAR BUILT]
# Index: []

# %%
df6 = df4[df4['SQUARE FEET'] / df4['BEDS'] >= 50]
df6.shape
# Out:
# (26172, 8)

# %%
def remove_price_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby("CITY"):
        m = np.mean(subdf.PRICE)
        st = np.std(subdf.PRICE)
        reduced_df = subdf[(subdf.PRICE > (m - st)) & (subdf.PRICE <= (m + st))]
        df_out = pd.concat([df_out, reduced_df], ignore_index=True)
    return df_out

# %%
df7 = remove_price_outliers(df6)
df8 = df7.drop_duplicates()
df8.head(20)
# Out:
#                 PROPERTY TYPE          CITY     PRICE  BEDS  BATHS  \
# 0   Single Family Residential         Acton  620000.0   3.0    2.0
# 3   Single Family Residential         Acton  645000.0   2.0    2.0
# 4   Single Family Residential         Acton  640000.0   3.0    2.0
# 5   Single Family Residential         Acton  639000.0   4.0    4.0
# 6   Single Family Residential         Acton  720000.0   4.0    2.0
# 7   Single Family Residential         Acton  730000.0   4.0    2.5
# 8   Single Family Residential         Acton  754000.0   3.0    2.0
# 9   Single Family Residential         Acton  777000.0   2.0    2.0
# 10  Single Family Residential         Acton  795000.0   4.0    2.5
# 11  Single Family Residential         Acton  840000.0   4.0    2.0
# 12  Single Family Residential         Acton  830000.0   2.0    2.0
# 13  Single Family Residential         Acton  842500.0   2.0    2.0
# 14  Single Family Residential         Acton  880000.0   4.0    3.0
# 15  Single Family Residential         Acton  875000.0   4.0    3.0
# 16  Single Family Residential         Acton  902000.0   3.0    3.0
# 17  Single Family Residential         Acton  900000.0   4.0    2.5
# 18  Single Family Residential         Acton  900000.0   4.0    4.5
# 19  Single Family Residential         Acton  925000.0   4.0    3.0
# 20                  Townhouse  Agoura Hills  560000.0   2.0    3.0
# 21                  Townhouse  Agoura Hills  579900.0   2.0    2.0
#
#     SQUARE FEET  LOT SIZE  YEAR BUILT
# 0        1760.0  107850.0      1991.0
# 3        1800.0  121564.0      1983.0
# 4        1300.0  221284.0      1969.0
# 5        2259.0  209579.0      1993.0
# 6        1477.0  112070.0      1985.0
# 7        2194.0  455865.0      1989.0
# 8        1803.0  108900.0      1971.0
# 9        1272.0  152821.0      1990.0
# 10       2547.0  212927.0      1992.0
# 11       2056.0   39985.0      1989.0
# 12       1778.0  432125.0      1995.0
# 13       1316.0  693543.0      1956.0
# 14       2559.0   53573.0      2004.0
# 15       2003.0  208241.0      1976.0
# 16       2192.0   61627.0      1983.0
# 17       1972.0   44431.0      1997.0
# 18       3350.0   67362.0      1983.0
# 19       2610.0   55404.0      1978.0
# 20        981.0   81154.0      1979.0
# 21       1127.0   86410.0      1973.0

# %%
df8.shape
# Out:
# (20088, 8)

# %%
# create scatter plot to visualize 3 bhk costing less than 2 bhk 
def plot_scatter_chart(df,CITY):
    beds2 = df[(df.CITY == CITY) & (df.BEDS == 2)]
    beds3 = df[(df.CITY == CITY) & (df.BEDS == 3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(beds2['SQUARE FEET'], beds2.PRICE, color= 'blue', label = '2 BEDS', s = 50)
    plt.scatter(beds3['SQUARE FEET'], beds3.PRICE, marker = '+', color='green',label='3 BEDS', s = 50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price Per Square Feet")
    plt.title(CITY)
    plt.legend()
    
plt.show(plot_scatter_chart(df7,"Lancaster"))

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)
plt.hist(df8.PRICE/df8['SQUARE FEET'], rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
plt.show()

# %%
df8.BATHS.unique()
# Out:
# array([ 2. ,  4. ,  2.5,  3. ,  4.5,  1.5,  5. ,  1. ,  3.5,  7.5,  6. ,
#         5.5,  6.5,  9. ,  8. ,  7. , 12. , 10.5])

# %%
df8[df8.BATHS > 10]
# Out:
#                    PROPERTY TYPE                 CITY      PRICE  BEDS  BATHS  \
# 11261  Single Family Residential          Los Angeles  1750000.0  12.0   12.0
# 16112  Single Family Residential  San Juan Capistrano  3320000.0   9.0   10.5
#
#        SQUARE FEET  LOT SIZE  YEAR BUILT
# 11261      16080.0    6998.0      1920.0
# 16112       9284.0   15478.0      2019.0

# %%
plt.hist(df8.BATHS, rwidth=0.8)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
plt.show()

# %%
df9 = df8[df8.BATHS < df8.BEDS + 2]
df10 = df9[df9.BEDS > 0]

# %%
df10.groupby('BEDS')['BEDS'].agg('count')
# Out:
# BEDS
# 1.0      501
# 2.0     3940
# 3.0     9258
# 4.0     5038
# 5.0     1068
# 6.0      169
# 7.0       35
# 8.0       12
# 9.0        2
# 10.0       3
# 11.0       1
# 12.0       2
# 13.0       1
# Name: BEDS, dtype: int64

# %%
df10.head(20)
# Out:
#                 PROPERTY TYPE          CITY     PRICE  BEDS  BATHS  \
# 0   Single Family Residential         Acton  620000.0   3.0    2.0
# 3   Single Family Residential         Acton  645000.0   2.0    2.0
# 4   Single Family Residential         Acton  640000.0   3.0    2.0
# 5   Single Family Residential         Acton  639000.0   4.0    4.0
# 6   Single Family Residential         Acton  720000.0   4.0    2.0
# 7   Single Family Residential         Acton  730000.0   4.0    2.5
# 8   Single Family Residential         Acton  754000.0   3.0    2.0
# 9   Single Family Residential         Acton  777000.0   2.0    2.0
# 10  Single Family Residential         Acton  795000.0   4.0    2.5
# 11  Single Family Residential         Acton  840000.0   4.0    2.0
# 12  Single Family Residential         Acton  830000.0   2.0    2.0
# 13  Single Family Residential         Acton  842500.0   2.0    2.0
# 14  Single Family Residential         Acton  880000.0   4.0    3.0
# 15  Single Family Residential         Acton  875000.0   4.0    3.0
# 16  Single Family Residential         Acton  902000.0   3.0    3.0
# 17  Single Family Residential         Acton  900000.0   4.0    2.5
# 18  Single Family Residential         Acton  900000.0   4.0    4.5
# 19  Single Family Residential         Acton  925000.0   4.0    3.0
# 20                  Townhouse  Agoura Hills  560000.0   2.0    3.0
# 21                  Townhouse  Agoura Hills  579900.0   2.0    2.0
#
#     SQUARE FEET  LOT SIZE  YEAR BUILT
# 0        1760.0  107850.0      1991.0
# 3        1800.0  121564.0      1983.0
# 4        1300.0  221284.0      1969.0
# 5        2259.0  209579.0      1993.0
# 6        1477.0  112070.0      1985.0
# 7        2194.0  455865.0      1989.0
# 8        1803.0  108900.0      1971.0
# 9        1272.0  152821.0      1990.0
# 10       2547.0  212927.0      1992.0
# 11       2056.0   39985.0      1989.0
# 12       1778.0  432125.0      1995.0
# 13       1316.0  693543.0      1956.0
# 14       2559.0   53573.0      2004.0
# 15       2003.0  208241.0      1976.0
# 16       2192.0   61627.0      1983.0
# 17       1972.0   44431.0      1997.0
# 18       3350.0   67362.0      1983.0
# 19       2610.0   55404.0      1978.0
# 20        981.0   81154.0      1979.0
# 21       1127.0   86410.0      1973.0

# %%
dummies = pd.get_dummies(df10.CITY, dtype=int)
dummies.head(3)
# Out:
#    Acton  Agoura Hills  Agua Dulce  Alhambra  Aliso Viejo  Altadena  Anaheim  \
# 0      1             0           0         0            0         0        0
# 3      1             0           0         0            0         0        0
# 4      1             0           0         0            0         0        0
#
#    Anaheim Hills  Arcadia  Arleta  ...  West Hills  West Hollywood  \
# 0              0        0       0  ...           0               0
# 3              0        0       0  ...           0               0
# 4              0        0       0  ...           0               0
#
#    Westlake Village  Westminster  Whittier  Wilmington  Winnetka  \
# 0                 0            0         0           0         0
# 3                 0            0         0           0         0
# 4                 0            0         0           0         0
#
#    Woodland Hills  Yorba Linda  other
# 0               0            0      0
# 3               0            0      0
# 4               0            0      0
#
# [3 rows x 184 columns]

# %%
df11 = pd.concat([df10,dummies.drop("other", axis= "columns")], axis= "columns")

# %%
df12 = df11.drop("CITY", axis="columns")
df12.head(2)
# Out:
#                PROPERTY TYPE     PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  \
# 0  Single Family Residential  620000.0   3.0    2.0       1760.0  107850.0
# 3  Single Family Residential  645000.0   2.0    2.0       1800.0  121564.0
#
#    YEAR BUILT  Acton  Agoura Hills  Agua Dulce  ...  West Covina  West Hills  \
# 0      1991.0      1             0           0  ...            0           0
# 3      1983.0      1             0           0  ...            0           0
#
#    West Hollywood  Westlake Village  Westminster  Whittier  Wilmington  \
# 0               0                 0            0         0           0
# 3               0                 0            0         0           0
#
#    Winnetka  Woodland Hills  Yorba Linda
# 0         0               0            0
# 3         0               0            0
#
# [2 rows x 190 columns]

# %%
# 1. Create dummies
dummies = pd.get_dummies(df12['PROPERTY TYPE'], dtype=int)

# 2. Drop the original 'PROPERTY TYPE' column
df12 = df12.drop('PROPERTY TYPE', axis=1)

# 3. Concatenate the dummies
df13 = pd.concat([df12, dummies], axis='columns')

# %%
dummies.head()
# Out:
#    Condo/Co-op  Mobile/Manufactured Home  Multi-Family (2-4 Unit)  \
# 0            0                         0                        0
# 3            0                         0                        0
# 4            0                         0                        0
# 5            0                         0                        0
# 6            0                         0                        0
#
#    Multi-Family (5+ Unit)  Single Family Residential  Townhouse
# 0                       0                          1          0
# 3                       0                          1          0
# 4                       0                          1          0
# 5                       0                          1          0
# 6                       0                          1          0

# %%
df13 = df12.drop("PROPERTY TYPE", axis="columns")
df13.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[384], line 1
# ----> 1 df13 = df12.drop("PROPERTY TYPE", axis="columns")
#       2 df13.head(2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['PROPERTY TYPE'] not found in axis"

# %%
# Remove top 1% of houses by price:
cutoff_1 = df13['PRICE'].quantile(0.99)
df_1_removed = df13[df13['PRICE'] <= cutoff_1]
print("Rows removed for 1% cutoff:", len(df13) - len(df_1_removed))
print("New df shape (1% removed):", df_1_removed.shape)
# Out:
# Rows removed for 1% cutoff: 201
# New df shape (1% removed): (19829, 195)

# %%
# Remove top 5% of houses by price:
cutoff_5 = df13['PRICE'].quantile(0.95)
df_5_removed = df13[df13['PRICE'] <= cutoff_5]
print("Rows removed for 5% cutoff:", len(df13) - len(df_5_removed))
print("New df shape (5% removed):", df_5_removed.shape)
# Out:
# Rows removed for 5% cutoff: 1002
# New df shape (5% removed): (19028, 195)

# %%
import matplotlib.pyplot as plt
plt.hist(df13['PRICE'], bins=50)
plt.show()

# %%
import numpy as np
df13['log_price'] = np.log1p(df13['PRICE'])
df13.shape
# Out:
# (20030, 196)

# %%
import numpy as np
skew_val = df13['PRICE'].skew()
print("Skewness of PRICE:", skew_val)
# Out:
# Skewness of PRICE: 2.4482620079859267

# %%
df_5_removed.loc[:, 'log_price'] = np.log1p(df_5_removed['PRICE'])
# Out:
# C:\Users\Boxi Lin\AppData\Local\Temp\ipykernel_31100\3872470739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_5_removed.loc[:, 'log_price'] = np.log1p(df_5_removed['PRICE'])

# %%
X = df_5_removed.drop(['PRICE', 'log_price'], axis='columns')
X = X.drop('LOT SIZE', axis=1)
y = df_5_removed['log_price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.7545613908075551

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_test_pred_log = lr_clf.predict(X_test)
mse_log = mean_squared_error(y_test, y_test_pred_log)
r2_log = r2_score(y_test, y_test_pred_log)

print("MSE in log-space:", mse_log)
print("R² in log-space:", r2_log)
# Out:
# MSE in log-space: 0.043412623999469435
# R² in log-space: 0.7545613908075551

# %%
import numpy as np

y_test_pred = np.expm1(y_test_pred_log)  # inverse of log1p
y_test_actual = np.expm1(y_test)         # for actual test values

# Then compute metrics in original price space:
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae_price = mean_absolute_error(y_test_actual, y_test_pred)
mse_price = mean_squared_error(y_test_actual, y_test_pred)
rmse_price = np.sqrt(mse_price)
r2_price = r2_score(y_test_actual, y_test_pred)

print("MAE in price space:", mae_price)
print("RMSE in price space:", rmse_price)
print("R² in price space:", r2_price)
# Out:
# MAE in price space: 161264.00545187955
# RMSE in price space: 246858.94812623697
# R² in price space: 0.7171057300268252

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.74416242, 0.75603408, 0.72434666, 0.71252378, 0.76214964])

# %%
def predict_price(city, property_type, sqft, bath, beds, year_built, model, X_columns):
    import numpy as np
    
    # Create a zero vector with length equal to the number of features.
    x = np.zeros(len(X_columns))
    
    # Assign numeric features using the uppercase keys as in training.
    if 'SQUARE FEET' in X_columns:
        x[X_columns.get_loc('SQUARE FEET')] = sqft
    if 'BATHS' in X_columns:
        x[X_columns.get_loc('BATHS')] = bath
    if 'BEDS' in X_columns:
        x[X_columns.get_loc('BEDS')] = beds
    if 'YEAR BUILT' in X_columns:
        x[X_columns.get_loc('YEAR BUILT')] = year_built

    # One-hot encode the city.
    if city in X_columns:
        x[X_columns.get_loc(city)] = 1
    else:
        print(f"Warning: City '{city}' not found in training data.")

    # One-hot encode the property type.
    if property_type in X_columns:
        x[X_columns.get_loc(property_type)] = 1
    else:
        print(f"Warning: Property type '{property_type}' not found in training data.")

    # Predict log(price) using the model.
    predicted_log_price = model.predict([x])[0]
    # Convert from log(price) to price.
    predicted_price = np.expm1(predicted_log_price)
    
    return round(predicted_price, 2)

# %%
predict_price(
    city="Irvine",
    property_type="Townhouse",
    sqft=1200,
    bath=2,
    beds=2,
    year_built=1977,
    model=lr_clf,
    X_columns=X.columns
)
# Out:
# C:\Users\Boxi Lin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 1190035.96

# %%
dummies.head()
# Out:
#    Condo/Co-op  Mobile/Manufactured Home  Multi-Family (2-4 Unit)  \
# 0            0                         0                        0
# 3            0                         0                        0
# 4            0                         0                        0
# 5            0                         0                        0
# 6            0                         0                        0
#
#    Multi-Family (5+ Unit)  Single Family Residential  Townhouse
# 0                       0                          1          0
# 3                       0                          1          0
# 4                       0                          1          0
# 5                       0                          1          0
# 6                       0                          1          0

# %%
predict_price('Rowland Heights', 'Single Family Residential', 1300, 2, 3, 1940,model=lr_clf, X_columns=X.columns)
# Out:
# C:\Users\Boxi Lin\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 831320.49

# %%
import pickle
with open('la_county_prices_model.pickle', 'wb') as f:
    pickle.dump(lr_clf, f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json", "w") as f:
    f.write(json.dumps(columns))
